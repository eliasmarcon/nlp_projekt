# %%
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np
import os
from datetime import timedelta, datetime

# %%
df_llms_performance = pd.read_csv("../performance_statistics/overall_statistics.csv")
df_llms_performance.drop_duplicates(keep = 'first', inplace = True) # got one duplicate (due to rerun of the same model) in the dataset
df_llms_performance
# Out:
#                                                 Model  Accuracy    TN    FP  \
# 0   model_albert_base_0.0001_512_dataset_preproces...  0.547451     0  4244
# 1   model_albert_base_0.0001_512_dataset_preproces...  0.548198     0  4237
# 2   model_albert_base_2e-05_512_dataset_preprocess...  0.734272  2995  1249
# 3   model_albert_base_2e-05_512_dataset_preprocess...  0.700682  2773  1464
# 4   model_albert_base_5e-05_512_dataset_preprocess...  0.547451     0  4244
# 5   model_albert_base_5e-05_512_dataset_preprocess...  0.548198     0  4237
# 6   model_albert_base_0.0001_256_dataset_preproces...  0.547451     0  4244
# 7   model_albert_base_0.0001_256_dataset_preproces...  0.629985  2872  1365
# 8   model_albert_base_2e-05_256_dataset_preprocess...  0.722329  2932  1312
# 9   model_albert_base_2e-05_256_dataset_preprocess...  0.716571  2771  1466
# 10  model_albert_base_5e-05_256_dataset_preprocess...  0.547451     0  4244
# 11  model_albert_base_5e-05_256_dataset_preprocess...  0.716038  2466  1771
# 12  model_bert_base_0.0001_512_dataset_preprocesse...  0.547451     0  4244
# 13  model_bert_base_2e-05_512_dataset_preprocessed...  0.799851  3255   989
# 14  model_bert_base_5e-05_512_dataset_preprocessed...  0.547451     0  4244
# 15  model_bert_base_2e-05_512_dataset_preprocessed...  0.751120  3115  1122
# 16  model_bert_base_5e-05_512_dataset_preprocessed...  0.548198     0  4237
# 17  model_bert_base_0.0001_512_dataset_preprocesse...  0.548198     0  4237
# 18  model_bert_base_5e-05_256_dataset_preprocessed...  0.547451     0  4244
# 19  model_bert_base_2e-05_256_dataset_preprocessed...  0.796012  3208  1036
# 20  model_bert_base_0.0001_256_dataset_preprocesse...  0.547451     0  4244
# 21  model_bert_base_0.0001_256_dataset_preprocesse...  0.548198     0  4237
# 22  model_bert_base_2e-05_256_dataset_preprocessed...  0.745468  3035  1202
# 23  model_bert_base_5e-05_256_dataset_preprocessed...  0.548198     0  4237
# 24  model_distilbert_0.0001_512_dataset_preprocess...  0.547451     0  4244
# 25  model_distilbert_2e-05_512_dataset_preprocesse...  0.781830  3164  1080
# 26  model_distilbert_5e-05_512_dataset_preprocesse...  0.735125  2935  1309
# 27  model_distilbert_5e-05_512_dataset_preprocesse...  0.724142  2963  1274
# 28  model_distilbert_2e-05_512_dataset_preprocesse...  0.749200  3011  1226
# 29  model_distilbert_0.0001_512_dataset_preprocess...  0.548198     0  4237
# 30  model_distilbert_0.0001_256_dataset_preprocess...  0.547451     0  4244
# 31  model_distilbert_2e-05_256_dataset_preprocesse...  0.781083  3159  1085
# 32  model_distilbert_0.0001_256_dataset_preprocess...  0.548198     0  4237
# 33  model_distilbert_5e-05_256_dataset_preprocesse...  0.741309  2896  1348
# 34  model_distilbert_2e-05_256_dataset_preprocesse...  0.746534  3022  1215
# 35  model_distilbert_5e-05_256_dataset_preprocesse...  0.723928  2957  1280
# 36  model_roberta_0.0001_512_dataset_preprocessed_...  0.547451     0  4244
# 37  model_roberta_2e-05_512_dataset_preprocessed_n...  0.806569  3251   993
# 38  model_roberta_5e-05_512_dataset_preprocessed_n...  0.547451     0  4244
# 39  model_roberta_0.0001_512_dataset_preprocessed_...  0.548198     0  4237
# 40  model_roberta_5e-05_512_dataset_preprocessed_s...  0.548198     0  4237
# 41  model_roberta_2e-05_512_dataset_preprocessed_s...  0.744615  3009  1228
# 42  model_roberta_0.0001_256_dataset_preprocessed_...  0.547451     0  4244
# 43  model_roberta_5e-05_256_dataset_preprocessed_s...  0.548198     0  4237
# 44  model_roberta_2e-05_256_dataset_preprocessed_s...  0.746961  2973  1264
# 45  model_roberta_5e-05_256_dataset_preprocessed_n...  0.547451     0  4244
# 46  model_roberta_2e-05_256_dataset_preprocessed_n...  0.796225  3151  1093
# 47  model_roberta_0.0001_256_dataset_preprocessed_...  0.548198     0  4237
# 48  model_transformer_0.0001_512_dataset_preproces...  0.547451     0  4244
# 49  model_transformer_2e-05_512_dataset_preprocess...  0.818511  3357   887
# 50  model_transformer_5e-05_512_dataset_preprocess...  0.547451     0  4244
# 51  model_transformer_5e-05_512_dataset_preprocess...  0.548198     0  4237
# 52  model_transformer_2e-05_512_dataset_preprocess...  0.548198     0  4237
# 53  model_transformer_0.0001_512_dataset_preproces...  0.548198     0  4237
# 54  model_transformer_0.0001_256_dataset_preproces...  0.547451     0  4244
# 55  model_transformer_0.0001_256_dataset_preproces...  0.548198     0  4237
# 56  model_transformer_2e-05_256_dataset_preprocess...  0.700363  2042  2202
# 57  model_transformer_5e-05_256_dataset_preprocess...  0.547451     0  4244
# 58  model_transformer_2e-05_256_dataset_preprocess...  0.548198     0  4237
# 59  model_transformer_5e-05_256_dataset_preprocess...  0.548198     0  4237
#
#       FN    TP       MCC
# 0      0  5134  0.000000
# 1      0  5141  0.000000
# 2   1243  3891  0.463648
# 3   1343  3798  0.394364
# 4      0  5134  0.000000
# 5      0  5141  0.000000
# 6      0  5134  0.000000
# 7   2105  3036  0.267640
# 8   1292  3842  0.439386
# 9   1192  3949  0.425302
# 10     0  5134  0.000000
# 11   892  4249  0.424048
# 12     0  5134  0.000000
# 13   888  4246  0.595370
# 14     0  5134  0.000000
# 15  1212  3929  0.498600
# 16     0  5141  0.000000
# 17     0  5141  0.000000
# 18     0  5134  0.000000
# 19   877  4257  0.587321
# 20     0  5134  0.000000
# 21     0  5141  0.000000
# 22  1185  3956  0.485983
# 23     0  5141  0.000000
# 24     0  5134  0.000000
# 25   966  4168  0.558835
# 26  1175  3959  0.464162
# 27  1313  3828  0.443574
# 28  1126  4015  0.492758
# 29     0  5141  0.000000
# 30     0  5134  0.000000
# 31   968  4166  0.557307
# 32     0  5141  0.000000
# 33  1078  4056  0.475835
# 34  1162  3979  0.487783
# 35  1309  3832  0.443022
# 36     0  5134  0.000000
# 37   821  4313  0.608665
# 38     0  5134  0.000000
# 39     0  5141  0.000000
# 40     0  5141  0.000000
# 41  1167  3974  0.483828
# 42     0  5134  0.000000
# 43     0  5141  0.000000
# 44  1109  4032  0.487800
# 45     0  5134  0.000000
# 46   818  4316  0.587465
# 47     0  5141  0.000000
# 48     0  5134  0.000000
# 49   815  4319  0.633261
# 50     0  5134  0.000000
# 51     0  5141  0.000000
# 52     0  5141  0.000000
# 53     0  5141  0.000000
# 54     0  5134  0.000000
# 55     0  5141  0.000000
# 56   608  4526  0.400983
# 57     0  5134  0.000000
# 58     0  5141  0.000000
# 59     0  5141  0.000000

# %%
def extract_info(df):
    
    df['Modelname'] = df['Model'].apply(lambda x: "_".join(x.split("_")[1:x.split("_").index('dataset') - 2]))
    df['Max_length'] = df['Model'].apply(lambda x: int(x.split("_")[x.split("_").index('dataset') - 1]))
    df['Learning_rate'] = df['Model'].apply(lambda x: float(x.split("_")[x.split("_").index('dataset') - 2]))
    df['Dataset'] = df['Model'].apply(lambda x: "_".join(x.split("_")[x.split("_").index('dataset') + 2:]))

    df.drop('Model', axis=1, inplace=True)
    df.rename(columns={'Accuracy': 'Test Accuracy'}, inplace=True)

    df = df[['Modelname', 'Max_length', 'Learning_rate', 'Dataset', 'Test Accuracy', 'TN', 'FP', 'FN', 'TP', 'MCC']]
    # Return the modified DataFrame
    return df

# Apply the function to your DataFrame
df_llms_performance = extract_info(df_llms_performance.copy())  # Operate on a copy to avoid modifying original data
df_llms_performance.head()
# Out:
#      Modelname  Max_length  Learning_rate            Dataset  Test Accuracy  \
# 0  albert_base         512        0.00010  no_transformation       0.547451
# 1  albert_base         512        0.00010          stopwords       0.548198
# 2  albert_base         512        0.00002  no_transformation       0.734272
# 3  albert_base         512        0.00002          stopwords       0.700682
# 4  albert_base         512        0.00005  no_transformation       0.547451
#
#      TN    FP    FN    TP       MCC
# 0     0  4244     0  5134  0.000000
# 1     0  4237     0  5141  0.000000
# 2  2995  1249  1243  3891  0.463648
# 3  2773  1464  1343  3798  0.394364
# 4     0  4244     0  5134  0.000000

# %%
df_timing = pd.DataFrame()

for folder in os.listdir("../performance_statistics/"):
    
    # check if folder
    if not os.path.isdir(f"../performance_statistics/{folder}"):
        continue
    
    for file in os.listdir(f"../performance_statistics/{folder}/"):
        
        if file.endswith(".csv"):
            
            df = pd.read_csv(f"../performance_statistics/{folder}/{file}")
            df['Model'] = folder   
            
            # convert string time to datetime with hours, minutes and seconds
            df['Training_Time'] = df['Training_Time'].apply(lambda x: datetime.strptime(x, '%H:%M:%S').time())
            df['Validation_Time'] = df['Validation_Time'].apply(lambda x: datetime.strptime(x, '%H:%M:%S').time())
            
            # concat the dataframes
            df_timing = pd.concat([df_timing, df], ignore_index=True)

# %%
# Convert time strings to timedeltas
df_timing['Training_Time'] = df_timing['Training_Time'].apply(lambda x: timedelta(hours=x.hour, minutes=x.minute, seconds=x.second))
df_timing['Validation_Time'] = df_timing['Validation_Time'].apply(lambda x: timedelta(hours=x.hour, minutes=x.minute, seconds=x.second))

# %%
df2 = df_timing.groupby('Model').agg({'Training_Time' : 'mean', 'Validation_Time' : 'mean'}).reset_index()
df2['Avg_Training_Time'] = df2['Training_Time'].apply(lambda x: f"{x.seconds//60}m {x.seconds%60}s")
df2['Avg_Validation_Time'] = df2['Validation_Time'].apply(lambda x: f"{x.seconds//60}m {x.seconds%60}s")
df2.drop(['Training_Time', 'Validation_Time'], axis=1, inplace=True)
df2
# Out:
#          Model Avg_Training_Time Avg_Validation_Time
# 0  albert_base           17m 41s              3m 12s
# 1    bert_base           17m 58s              2m 47s
# 2   distilbert            9m 20s              1m 25s
# 3      roberta            18m 7s              2m 43s
# 4  transformer           16m 14s              2m 26s

# %% [markdown]
# ## Grouping the Dataframe

# %%
df_llms_performance['Precision'] = df_llms_performance['TP'] / (df_llms_performance['TP'] + df_llms_performance['FP'])
df_llms_performance['Recall'] = df_llms_performance['TP'] / (df_llms_performance['TP'] + df_llms_performance['FN'])

# %%
df_llms_performance.groupby(['Dataset', 'Max_length', 'Learning_rate', 'Modelname'])[['Test Accuracy', 'Precision', 'Recall', 'MCC']].mean()
# Out:
#                                                         Test Accuracy  \
# Dataset           Max_length Learning_rate Modelname
# no_transformation 256        0.00002       albert_base       0.722329
#                                            bert_base         0.796012
#                                            distilbert        0.781083
#                                            roberta           0.796225
#                                            transformer       0.700363
#                              0.00005       albert_base       0.547451
#                                            bert_base         0.547451
#                                            distilbert        0.741309
#                                            roberta           0.547451
#                                            transformer       0.547451
#                              0.00010       albert_base       0.547451
#                                            bert_base         0.547451
#                                            distilbert        0.547451
#                                            roberta           0.547451
#                                            transformer       0.547451
#                   512        0.00002       albert_base       0.734272
#                                            bert_base         0.799851
#                                            distilbert        0.781830
#                                            roberta           0.806569
#                                            transformer       0.818511
#                              0.00005       albert_base       0.547451
#                                            bert_base         0.547451
#                                            distilbert        0.735125
#                                            roberta           0.547451
#                                            transformer       0.547451
#                              0.00010       albert_base       0.547451
#                                            bert_base         0.547451
#                                            distilbert        0.547451
#                                            roberta           0.547451
#                                            transformer       0.547451
# stopwords         256        0.00002       albert_base       0.716571
#                                            bert_base         0.745468
#                                            distilbert        0.746534
#                                            roberta           0.746961
#                                            transformer       0.548198
#                              0.00005       albert_base       0.716038
#                                            bert_base         0.548198
#                                            distilbert        0.723928
#                                            roberta           0.548198
#                                            transformer       0.548198
#                              0.00010       albert_base       0.629985
#                                            bert_base         0.548198
#                                            distilbert        0.548198
#                                            roberta           0.548198
#                                            transformer       0.548198
#                   512        0.00002       albert_base       0.700682
#                                            bert_base         0.751120
#                                            distilbert        0.749200
#                                            roberta           0.744615
#                                            transformer       0.548198
#                              0.00005       albert_base       0.548198
#                                            bert_base         0.548198
#                                            distilbert        0.724142
#                                            roberta           0.548198
#                                            transformer       0.548198
#                              0.00010       albert_base       0.548198
#                                            bert_base         0.548198
#                                            distilbert        0.548198
#                                            roberta           0.548198
#                                            transformer       0.548198
#
#                                                         Precision    Recall  \
# Dataset           Max_length Learning_rate Modelname
# no_transformation 256        0.00002       albert_base   0.745440  0.748344
#                                            bert_base     0.804270  0.829178
#                                            distilbert    0.793373  0.811453
#                                            roberta       0.797929  0.840670
#                                            transformer   0.672711  0.881574
#                              0.00005       albert_base   0.547451  1.000000
#                                            bert_base     0.547451  1.000000
#                                            distilbert    0.750555  0.790027
#                                            roberta       0.547451  1.000000
#                                            transformer   0.547451  1.000000
#                              0.00010       albert_base   0.547451  1.000000
#                                            bert_base     0.547451  1.000000
#                                            distilbert    0.547451  1.000000
#                                            roberta       0.547451  1.000000
#                                            transformer   0.547451  1.000000
#                   512        0.00002       albert_base   0.757004  0.757889
#                                            bert_base     0.811079  0.827035
#                                            distilbert    0.794207  0.811843
#                                            roberta       0.812853  0.840086
#                                            transformer   0.829620  0.841254
#                              0.00005       albert_base   0.547451  1.000000
#                                            bert_base     0.547451  1.000000
#                                            distilbert    0.751519  0.771134
#                                            roberta       0.547451  1.000000
#                                            transformer   0.547451  1.000000
#                              0.00010       albert_base   0.547451  1.000000
#                                            bert_base     0.547451  1.000000
#                                            distilbert    0.547451  1.000000
#                                            roberta       0.547451  1.000000
#                                            transformer   0.547451  1.000000
# stopwords         256        0.00002       albert_base   0.729271  0.768138
#                                            bert_base     0.766964  0.769500
#                                            distilbert    0.766076  0.773974
#                                            roberta       0.761329  0.784283
#                                            transformer   0.548198  1.000000
#                              0.00005       albert_base   0.705814  0.826493
#                                            bert_base     0.548198  1.000000
#                                            distilbert    0.749609  0.745380
#                                            roberta       0.548198  1.000000
#                                            transformer   0.548198  1.000000
#                              0.00010       albert_base   0.689843  0.590547
#                                            bert_base     0.548198  1.000000
#                                            distilbert    0.548198  1.000000
#                                            roberta       0.548198  1.000000
#                                            transformer   0.548198  1.000000
#                   512        0.00002       albert_base   0.721779  0.738767
#                                            bert_base     0.777866  0.764248
#                                            distilbert    0.766075  0.780976
#                                            roberta       0.763937  0.773001
#                                            transformer   0.548198  1.000000
#                              0.00005       albert_base   0.548198  1.000000
#                                            bert_base     0.548198  1.000000
#                                            distilbert    0.750294  0.744602
#                                            roberta       0.548198  1.000000
#                                            transformer   0.548198  1.000000
#                              0.00010       albert_base   0.548198  1.000000
#                                            bert_base     0.548198  1.000000
#                                            distilbert    0.548198  1.000000
#                                            roberta       0.548198  1.000000
#                                            transformer   0.548198  1.000000
#
#                                                              MCC
# Dataset           Max_length Learning_rate Modelname
# no_transformation 256        0.00002       albert_base  0.439386
#                                            bert_base    0.587321
#                                            distilbert   0.557307
#                                            roberta      0.587465
#                                            transformer  0.400983
#                              0.00005       albert_base  0.000000
#                                            bert_base    0.000000
#                                            distilbert   0.475835
#                                            roberta      0.000000
#                                            transformer  0.000000
#                              0.00010       albert_base  0.000000
#                                            bert_base    0.000000
#                                            distilbert   0.000000
#                                            roberta      0.000000
#                                            transformer  0.000000
#                   512        0.00002       albert_base  0.463648
#                                            bert_base    0.595370
#                                            distilbert   0.558835
#                                            roberta      0.608665
#                                            transformer  0.633261
#                              0.00005       albert_base  0.000000
#                                            bert_base    0.000000
#                                            distilbert   0.464162
#                                            roberta      0.000000
#                                            transformer  0.000000
#                              0.00010       albert_base  0.000000
#                                            bert_base    0.000000
#                                            distilbert   0.000000
#                                            roberta      0.000000
#                                            transformer  0.000000
# stopwords         256        0.00002       albert_base  0.425302
#                                            bert_base    0.485983
#                                            distilbert   0.487783
#                                            roberta      0.487800
#                                            transformer  0.000000
#                              0.00005       albert_base  0.424048
#                                            bert_base    0.000000
#                                            distilbert   0.443022
#                                            roberta      0.000000
#                                            transformer  0.000000
#                              0.00010       albert_base  0.267640
#                                            bert_base    0.000000
#                                            distilbert   0.000000
#                                            roberta      0.000000
#                                            transformer  0.000000
#                   512        0.00002       albert_base  0.394364
#                                            bert_base    0.498600
#                                            distilbert   0.492758
#                                            roberta      0.483828
#                                            transformer  0.000000
#                              0.00005       albert_base  0.000000
#                                            bert_base    0.000000
#                                            distilbert   0.443574
#                                            roberta      0.000000
#                                            transformer  0.000000
#                              0.00010       albert_base  0.000000
#                                            bert_base    0.000000
#                                            distilbert   0.000000
#                                            roberta      0.000000
#                                            transformer  0.000000

# %% [markdown]
# ## Extracting best Models

# %%
df_llms_performance = df_llms_performance.sort_values(by = 'Test Accuracy', ascending = False)
df_llms_performance = df_llms_performance[0:5]
df_llms_performance
# Out:
#       Modelname  Max_length  Learning_rate            Dataset  Test Accuracy  \
# 49  transformer         512        0.00002  no_transformation       0.818511
# 37      roberta         512        0.00002  no_transformation       0.806569
# 13    bert_base         512        0.00002  no_transformation       0.799851
# 46      roberta         256        0.00002  no_transformation       0.796225
# 19    bert_base         256        0.00002  no_transformation       0.796012
#
#       TN    FP   FN    TP       MCC  Precision    Recall
# 49  3357   887  815  4319  0.633261   0.829620  0.841254
# 37  3251   993  821  4313  0.608665   0.812853  0.840086
# 13  3255   989  888  4246  0.595370   0.811079  0.827035
# 46  3151  1093  818  4316  0.587465   0.797929  0.840670
# 19  3208  1036  877  4257  0.587321   0.804270  0.829178

# %%
for row in df_llms_performance.iterrows():
    
    TN = row[1]['TN']
    FP = row[1]['FP']
    FN = row[1]['FN']
    TP = row[1]['TP']
    
    test_accuracy = row[1]['Test Accuracy'] * 100

    # Print the confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix = np.array([[TN, FP], [FN, TP]]), display_labels= ['Not Hate', 'Hate'])

    # Create the figure and axes
    disp.plot()
    # Set the suptitle (main title above the plot)
    plt.title(f"Model: {row[1]['Modelname']} | Test Accuracy: {test_accuracy:.2f}% | MCC: {row[1]['MCC']:.2f}")
    plt.show()
